# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Load the Dataset**

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk(r"C:\Users\Ravi Vishwakarma\Downloads\archive (5)"):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
paths[:5]
# Out:
# ['C:\\Users\\Ravi Vishwakarma\\Downloads\\archive (5)\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_back_angry.wav',
#  'C:\\Users\\Ravi Vishwakarma\\Downloads\\archive (5)\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bar_angry.wav',
#  'C:\\Users\\Ravi Vishwakarma\\Downloads\\archive (5)\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_base_angry.wav',
#  'C:\\Users\\Ravi Vishwakarma\\Downloads\\archive (5)\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bath_angry.wav',
#  'C:\\Users\\Ravi Vishwakarma\\Downloads\\archive (5)\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bean_angry.wav']

# %%
labels[:5]
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']

# %%
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech  label
# 0  C:\Users\Ravi Vishwakarma\Downloads\archive (5...  angry
# 1  C:\Users\Ravi Vishwakarma\Downloads\archive (5...  angry
# 2  C:\Users\Ravi Vishwakarma\Downloads\archive (5...  angry
# 3  C:\Users\Ravi Vishwakarma\Downloads\archive (5...  angry
# 4  C:\Users\Ravi Vishwakarma\Downloads\archive (5...  angry

# %%
df['label'].value_counts()
# Out:
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: label, dtype: int64

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
sns.countplot(data=df, x='label')
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(8,3))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(8,3))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %% [markdown]
# **Fear**

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Angry**

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Disgust**

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Neutral**

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Sad**

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Ps**

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Happy**

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **Feature Extraction**

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.96986206e+02,  7.74405365e+01, -1.95927906e+01, -2.16666889e+01,
#        -2.11275506e+00,  1.00753632e+01, -2.03667068e+01, -6.09244919e+00,
#        -7.21228361e+00, -5.57365894e-01, -1.83255327e+00,  2.02101514e-01,
#         7.27551103e-01,  1.31773770e+00,  2.88633752e+00,  2.85579133e+00,
#        -4.71292162e+00, -4.43651056e+00, -1.62115920e+00, -1.02398405e+01,
#        -7.55126143e+00, -1.79688025e+00, -7.03765202e+00,  9.43658447e+00,
#         8.35585499e+00,  2.17123604e+01,  1.92169895e+01,  2.03489265e+01,
#         1.34133663e+01,  8.33917141e+00,  3.94722402e-01,  5.11131477e+00,
#         9.56873894e+00,  5.45486784e+00,  2.50996375e+00, -1.82390714e+00,
#         4.86896276e+00,  9.31392384e+00,  2.08915019e+00, -1.90649128e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-396.9862, 77.44054, -19.59279, -21.666689, -...
# 1       [-465.73267, 98.77373, 0.65600896, -32.74544, ...
# 2       [-429.79196, 46.124, 1.5550478, -0.21709539, 2...
# 3       [-403.46118, 76.32369, -12.531774, -22.288858,...
# 4       [-434.05756, 77.4455, 10.8655, 16.092943, 8.04...
#                               ...
# 2795    [-553.2201, 89.83577, 27.215466, 16.407124, 19...
# 2796    [-589.23676, 96.20408, 36.96118, 15.014448, 28...
# 2797    [-533.41815, 85.43242, 27.791998, 19.307178, 2...
# 2798    [-548.6142, 110.16424, 31.910236, 12.572517, 2...
# 2799    [-549.2962, 102.374565, 32.268833, 26.261616, ...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %%
pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (3.5.0)
# Requirement already satisfied: h5py in c:\programdata\anaconda3\lib\site-packages (from keras) (3.6.0)
# Requirement already satisfied: optree in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from keras) (0.12.1)
# Requirement already satisfied: rich in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from keras) (13.8.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from keras) (21.3)
# Requirement already satisfied: absl-py in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from keras) (2.1.0)
# Requirement already satisfied: ml-dtypes in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from keras) (0.5.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from keras) (1.21.5)
# Requirement already satisfied: namex in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from keras) (0.0.8)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->keras) (3.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install optree
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: optree in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (0.12.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from optree) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (61.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.26.4)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.12.1)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.66.2)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.31.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.12.1)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.5)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (21.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.27.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.12.2)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.37.1)
# Requirement already satisfied: optree in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.12.1)
# Requirement already satisfied: namex in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: rich in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.8.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.0.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.17.0->tensorflow) (3.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\ravi vishwakarma\appdata\roaming\python\python39\site-packages (1.26.4)
# Collecting numpy
#   Downloading numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-2.0.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Ravi Vishwakarma\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# tensorflow-intel 2.17.0 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.0.2 which is incompatible.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 2.0.2 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 2.0.2 which is incompatible.

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense, LSTM, Dropout
#       4 model = Sequential([
#       5     LSTM(256, return_sequences=False, input_shape=(40,1)),
#       6     Dropout(0.2),
#    (...)
#      11     Dense(7, activation='softmax')
#      12 ])
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\__init__.py:4, in <module>
#       1 import os
#       3 # DO NOT EDIT. Generated by api_gen.sh
# ----> 4 from keras.api import DTypePolicy
#       5 from keras.api import FloatDTypePolicy
#       6 from keras.api import Function
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\api\__init__.py:8, in <module>
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.api import activations
#       9 from keras.api import applications
#      10 from keras.api import backend
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\api\activations\__init__.py:7, in <module>
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.src.activations import deserialize
#       8 from keras.src.activations import get
#       9 from keras.src.activations import serialize
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\__init__.py:1, in <module>
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\activations\__init__.py:3, in <module>
#       1 import types
# ----> 3 from keras.src.activations.activations import elu
#       4 from keras.src.activations.activations import exponential
#       5 from keras.src.activations.activations import gelu
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\activations\activations.py:1, in <module>
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#       3 from keras.src.api_export import keras_export
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\backend\__init__.py:9, in <module>
#       3 if backend() == "torch":
#       4     # When using the torch backend,
#       5     # torch needs to be imported first, otherwise it will segfault
#       6     # upon import.
#       7     import torch
# ----> 9 from keras.src.backend.common.dtypes import result_type
#      10 from keras.src.backend.common.keras_tensor import KerasTensor
#      11 from keras.src.backend.common.keras_tensor import any_symbolic_tensors
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\backend\common\__init__.py:2, in <module>
#       1 from keras.src.backend.common import backend_utils
# ----> 2 from keras.src.backend.common.dtypes import result_type
#       3 from keras.src.backend.common.variables import AutocastScope
#       4 from keras.src.backend.common.variables import KerasVariable
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\backend\common\dtypes.py:5, in <module>
#       3 from keras.src.api_export import keras_export
#       4 from keras.src.backend import config
# ----> 5 from keras.src.backend.common.variables import standardize_dtype
#       7 BOOL_TYPES = ("bool",)
#       8 INT_TYPES = (
#       9     "uint8",
#      10     "uint16",
#    (...)
#      16     "int64",
#      17 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\backend\common\variables.py:12, in <module>
#      10 from keras.src.backend.common.stateless_scope import in_stateless_scope
#      11 from keras.src.utils.module_utils import tensorflow as tf
# ---> 12 from keras.src.utils.naming import auto_name
#      15 class KerasVariable:
#      16     """Represents a backend-agnostic variable in Keras.
#      17
#      18     A `Variable` acts as a container for state. It holds a tensor value and can
#    (...)
#      78     ```
#      79     """
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\__init__.py:1, in <module>
# ----> 1 from keras.src.utils.audio_dataset_utils import audio_dataset_from_directory
#       2 from keras.src.utils.dataset_utils import split_dataset
#       3 from keras.src.utils.file_utils import get_file
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\audio_dataset_utils.py:4, in <module>
#       1 import numpy as np
#       3 from keras.src.api_export import keras_export
# ----> 4 from keras.src.utils import dataset_utils
#       5 from keras.src.utils.module_utils import tensorflow as tf
#       6 from keras.src.utils.module_utils import tensorflow_io as tfio
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\dataset_utils.py:9, in <module>
#       5 from multiprocessing.pool import ThreadPool
#       7 import numpy as np
# ----> 9 from keras.src import tree
#      10 from keras.src.api_export import keras_export
#      11 from keras.src.utils import io_utils
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\tree\__init__.py:1, in <module>
# ----> 1 from keras.src.tree.tree_api import assert_same_structure
#       2 from keras.src.tree.tree_api import flatten
#       3 from keras.src.tree.tree_api import is_nested
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\tree\tree_api.py:6, in <module>
#       3 from keras.src.utils.module_utils import optree
#       5 if optree.available:
# ----> 6     from keras.src.tree import optree_impl as tree_impl
#       7 elif dmtree.available:
#       8     from keras.src.tree import dmtree_impl as tree_impl
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\src\tree\optree_impl.py:17, in <module>
#      15 # Register backend-specific node classes
#      16 if backend() == "tensorflow":
# ---> 17     from tensorflow.python.trackable.data_structures import ListWrapper
#      19     optree.register_pytree_node(
#      20         ListWrapper,
#      21         lambda x: (x, None),
#      22         lambda metadata, children: ListWrapper(list(children)),
#      23         namespace="keras",
#      24     )
#      27 def is_nested(structure):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\trackable\data_structures.py:27, in <module>
#      24   from .....third_party import wrapt  # pylint: disable=relative-beyond-top-level
#      26 from tensorflow.python.eager import def_function
# ---> 27 from tensorflow.python.eager import function as defun
#      28 from tensorflow.python.ops import variables
#      29 from tensorflow.python.trackable import base
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\__init__.py:47, in <module>
#      44 from tensorflow.python import tf2 as _tf2
#      45 _tf2.enable()
# ---> 47 from tensorflow._api.v2 import __internal__
#      48 from tensorflow._api.v2 import __operators__
#      49 from tensorflow._api.v2 import audio
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11, in <module>
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
#      13 from tensorflow._api.v2.__internal__ import feature_column
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\__internal__\distribute\__init__.py:8, in <module>
#       3 """Public API for tf._api.v2.__internal__.distribute namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__.distribute import combinations
#       9 from tensorflow._api.v2.__internal__.distribute import interim
#      10 from tensorflow._api.v2.__internal__.distribute import multi_process_runner
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\__internal__\distribute\combinations\__init__.py:8, in <module>
#       3 """Public API for tf._api.v2.__internal__.distribute.combinations namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.distribute.combinations import env # line: 456
#       9 from tensorflow.python.distribute.combinations import generate # line: 365
#      10 from tensorflow.python.distribute.combinations import in_main_process # line: 418
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\distribute\combinations.py:33, in <module>
#      29 import six
#      32 from tensorflow.python.client import session
# ---> 33 from tensorflow.python.distribute import collective_all_reduce_strategy
#      34 from tensorflow.python.distribute import distribute_lib
#      35 from tensorflow.python.distribute import multi_process_runner
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\distribute\collective_all_reduce_strategy.py:25, in <module>
#      23 from tensorflow.core.protobuf import tensorflow_server_pb2
#      24 from tensorflow.python.distribute import collective_util
# ---> 25 from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#      26 from tensorflow.python.distribute import cross_device_utils
#      27 from tensorflow.python.distribute import device_util
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\distribute\cross_device_ops.py:28, in <module>
#      26 from tensorflow.python.client import device_lib
#      27 from tensorflow.python.distribute import collective_util
# ---> 28 from tensorflow.python.distribute import cross_device_utils
#      29 from tensorflow.python.distribute import device_util
#      30 from tensorflow.python.distribute import distribute_utils
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\distribute\cross_device_utils.py:22, in <module>
#      19 from typing import Callable, List, Optional, Union
#      21 from tensorflow.python.distribute import collective_util
# ---> 22 from tensorflow.python.distribute import values as value_lib
#      23 from tensorflow.python.eager import backprop_util
#      24 from tensorflow.python.eager import context
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\distribute\values.py:23, in <module>
#      21 from tensorflow.core.protobuf import struct_pb2
#      22 from tensorflow.python.distribute import device_util
# ---> 23 from tensorflow.python.distribute import distribute_lib
#      24 from tensorflow.python.distribute import packed_distributed_variable as packed
#      25 from tensorflow.python.distribute import reduce_util
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\distribute\distribute_lib.py:205, in <module>
#     203 from tensorflow.python.autograph.core import ag_ctx as autograph_ctx
#     204 from tensorflow.python.autograph.impl import api as autograph
# --> 205 from tensorflow.python.data.ops import dataset_ops
#     206 from tensorflow.python.distribute import collective_util
#     207 from tensorflow.python.distribute import device_util
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\data\ops\dataset_ops.py:34, in <module>
#      32 from tensorflow.python.data.ops import dataset_autograph
#      33 from tensorflow.python.data.ops import debug_mode
# ---> 34 from tensorflow.python.data.ops import iterator_ops
#      35 from tensorflow.python.data.ops import options as options_lib
#      36 from tensorflow.python.data.ops import structured_function
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\data\ops\iterator_ops.py:45, in <module>
#      43 from tensorflow.python.saved_model import nested_structure_coder
#      44 from tensorflow.python.trackable import base as trackable
# ---> 45 from tensorflow.python.training.saver import BaseSaverBuilder
#      46 from tensorflow.python.util import deprecation
#      47 from tensorflow.python.util.compat import collections_abc
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\training\saver.py:50, in <module>
#      48 from tensorflow.python.saved_model.pywrap_saved_model import metrics
#      49 from tensorflow.python.trackable import base as trackable
# ---> 50 from tensorflow.python.training import py_checkpoint_reader
#      51 from tensorflow.python.training import training_util
#      52 from tensorflow.python.training.saving import saveable_object
#
# File ~\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\training\py_checkpoint_reader.py:19, in <module>
#      17 from tensorflow.python.framework import errors_impl
#      18 from tensorflow.python.util import compat
# ---> 19 from tensorflow.python.util._pywrap_checkpoint_reader import CheckpointReader
#      20 from tensorflow.python.util.tf_export import tf_export
#      23 def error_translator(e):
#
# SystemError: initialization of _pywrap_checkpoint_reader raised unreported exception

# %%
# Train the model
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
